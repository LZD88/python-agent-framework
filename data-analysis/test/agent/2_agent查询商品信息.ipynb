# %%
from langchain_community.chat_models import ChatTongyi
from langchain_core.tools import tool
from langchain.agents import create_agent

# %%
# 1.创建 tool
@tool(description="根据商品goods_id去查询商品信息")
def get_goods_info_by_id(goods_id: int) -> str | None:
    # 模拟数据库查询工作
    goods_info = {
        1: "爱疯手机",
        2: "华为电脑"
    }
    if goods_id not in goods_info:
        print(f"id为{goods_id}的商品不存在")
        return None
    goods = goods_info[goods_id]
    print(f"id为{goods_id}的商品为：{goods}")
    return goods

# %%
# 2. 创建 Agent
agent = create_agent(
    model=ChatTongyi(model="qwen3-max"), # 给 Agent 提供大脑
    tools=[get_goods_info_by_id], # 给 Agent 提供工具
    system_prompt="你是一个商品信息查询助手，如果用户传入商品ID，请你帮他查询是什么商品"
)

# %%
# 3.调用 agent 去帮我们查询商品信息
result = agent.invoke({
    "messages": [{"role": "user", "content": "商品id为1，这个是一个什么商品"}]
})
# Out:
# id为1的商品为：爱疯手机

# %%
# 4.打印结果
# print(type(result)) # <class 'dict'>
print(result)
print(len(result['messages']))
# print(result['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='商品id为1，这个是一个什么商品', additional_kwargs={}, response_metadata={}, id='cc7db0fe-fa60-46ec-9b6d-55c983251be6'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"goods_id": 1}', 'name': 'get_goods_info_by_id'}, 'id': 'call_a54eb50ecc124a69b9233774', 'index': 0, 'type': 'function'}]}, response_metadata={'model_name': 'qwen3-max', 'finish_reason': 'tool_calls', 'request_id': '0cfb1220-ab19-9afc-a71f-d9bf54116be9', 'token_usage': {'input_tokens': 289, 'output_tokens': 25, 'prompt_tokens_details': {'cached_tokens': 192}, 'total_tokens': 314}}, id='lc_run--019eca29-1078-77f3-8dcb-382411176621-0', tool_calls=[{'name': 'get_goods_info_by_id', 'args': {'goods_id': 1}, 'id': 'call_a54eb50ecc124a69b9233774', 'type': 'tool_call'}], invalid_tool_calls=[]), ToolMessage(content='爱疯手机', name='get_goods_info_by_id', id='e88a91e3-18a0-485e-bae9-f6e3a5405c58', tool_call_id='call_a54eb50ecc124a69b9233774'), AIMessage(content='商品ID为1的商品是“爱疯手机”。', additional_kwargs={}, response_metadata={'model_name': 'qwen3-max', 'finish_reason': 'stop', 'request_id': 'df9bff04-2cd4-9646-bf30-5cb7e00b8e70', 'token_usage': {'input_tokens': 332, 'output_tokens': 11, 'prompt_tokens_details': {'cached_tokens': 256}, 'total_tokens': 343}}, id='lc_run--019eca29-1579-7783-b453-6de06c185322-0', tool_calls=[], invalid_tool_calls=[])]}
# 4
