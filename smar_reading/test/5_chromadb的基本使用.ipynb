# %%
from langchain_community.embeddings import DashScopeEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
# Out:
# C:\Users\86178\AppData\Local\Temp\ipykernel_10784\1607947919.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import DashScopeEmbeddings

# %%
# 1.创建 Chroma 客户端
# 第一次运行：创建新的 collection
# 第二次运行：自动加载已有的 collection
chroma_db = Chroma(
    persist_directory="./chroma_db",
    # 表？集合
    collection_name="test-collection",
    # 嵌入模型
    embedding_function=DashScopeEmbeddings(),
    collection_metadata={"hnsw:space": "cosine"}  # 余弦相似度
)

# %%
# 2. 新增 document
data = [
    Document(page_content="猫坐在垫子上"),
    Document(page_content="一只猫在垫子上休息"),
    Document(page_content="今天天气很好")
]

chroma_db.add_documents(
    documents=data,
    ids=[f"id-{i}" for i in range(1, len(data) + 1)]
)
# Out:
# ['id-1', 'id-2', 'id-3']

# %%
# 3.相似度查询（和mysql的where等值查询不一样，我们这里是基于相似度匹配）
user_query = "猫在哪？"
# result = chroma_db.similarity_search(user_query, k=2)
result = chroma_db.similarity_search_with_score(user_query, k=2)
print(type(result))
print(result)
# Out:
# <class 'list'>
# [(Document(id='id-2', metadata={}, page_content='一只猫在垫子上休息'), 0.38093870878219604), (Document(id='id-1', metadata={}, page_content='猫坐在垫子上'), 0.45420587062835693)]

# %%
# 4.根据id进行删除
chroma_db.delete("id-2")
user_query = "猫在哪？"
result = chroma_db.similarity_search(user_query, k=1)
print(type(result))
print(result)
# Out:
# <class 'list'>
# [Document(id='id-1', metadata={}, page_content='猫坐在垫子上')]
